# %%
import partitura as pt
import torch
import torch.nn as nn
from torch.nn import functional as F
import numpy as np
import os
import pandas as pd

# %% [markdown]
# # Pitch Spelling with Partitura
#
# Have you always been bad at spelling bee, do you find that spelling notes makes this even worse. Your time of struggling is over.... Today we going to teach a Model to learn how to *pitch* spell.
#
# ### Definition
#
# Spelling a pitch relates to the system of naming notes by letters (A-G) and sharp(#) and flat (♭) signs - and sometimes double sharp and flat signs, resulting in names or 'spellings' like 'A♭', 'D#', 'F♭♭'.
#
# Translating between frequencies in Hz and such names is non-trivial. You need to consider :
#
# -  The 'concert pitch' you are taking as a reference
# - The temperament in which the piece is played
# - The overall key that the music would be notated in
# - Use of the correct enharmonic equivalents for accidentals (Using the correct enharmonic equivalent, Purpose of double-sharps and double-flats?)
#
# If translating between, say, MIDI note numbers and 'spelled' names, the first two steps can be skipped.
#
# Spelled pitch names often have an octave number appended for disambiguation - e.g. 'A♭3', 'D#5'.
#
#
# ### Some Spelling algorithms
#
# Partitura contains an implementation for a standard algorithm for Pitch Spelling. The algorithm in question is called ps13 created by Meredith and al.:
#
#     The ps13 pitch spelling algorithm, D Meredith - Journal of New Music Research, 2006
#
# Some notable algorithms and currect SOTA is PKSpell.
#
#     PKSpell: Data-driven pitch spelling and key signature estimation
#     F Foscarin, N Audebert, R Fournier-S'Niehotta, 2021
#
#
# Let's first download a pitch spelling dataset.

# %%
# !wget https://github.com/CPJKU/asap-dataset/archive/refs/heads/note_alignments.zip
# Out:
# --2022-10-27 12:26:52--  https://github.com/CPJKU/asap-dataset/archive/refs/heads/note_alignments.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/CPJKU/asap-dataset/zip/refs/heads/note_alignments [following]
# --2022-10-27 12:26:52--  https://codeload.github.com/CPJKU/asap-dataset/zip/refs/heads/note_alignments
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘note_alignments.zip’
#
# note_alignments.zip     [         <=>        ] 248.45M   782KB/s    in 4m 4s
#
# 2022-10-27 12:30:57 (1.02 MB/s) - ‘note_alignments.zip’ saved [260516656]
#
# unzip:  cannot find or open /content/note_alignments.zip, /content/note_alignments.zip.zip or /content/note_alignments.zip.ZIP.

# %%
# !unzip ./note_alignments.zip
# Out:
# Archive:  ./note_alignments.zip
# 32bd86d2d436b94e1a16643a31d397bd3a6b51d2
#    creating: asap-dataset-note_alignments/
#   inflating: asap-dataset-note_alignments/.gitignore
#    creating: asap-dataset-note_alignments/Bach/
#    creating: asap-dataset-note_alignments/Bach/Fugue/
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/Shi05M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_846/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Denisova06M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lee01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/LeeSH01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lin04M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Lou01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/MiyashitaM01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Mizumoto03M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/SunY01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/Zhou01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_848/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/LuA01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/MiyashitaM01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Ozaki01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/Richardson01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/WangA01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_854/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/LuoJ01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_856/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Bult-ItoS02M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lan01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/Lisiecki04M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/ToA01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/WangA01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/YuP01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_857/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/VuV01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/Zhang01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_858/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Ko04M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Nikiforov05M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/Tetzloff04M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/TuanS01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/YoungS01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/ZhangH04M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_860/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/Song04M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_862/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/LeeN01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/Shychko01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/TongB01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_863/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/SunD01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_864/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Rizikov01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/Teo01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/ZhangE01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_865/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/SOLOM02_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_866/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/HuNY01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/Sham01M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/midi_score.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_867/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_868/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_868/GonzalezJ05M.mid
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_868/GonzalezJ05M_annotations.txt
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_868/GonzalezJ05M_note_alignments/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_868/GonzalezJ05M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Bach/Fugue/bwv_868/GonzalezJ05M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_868/GonzalezJ05M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_868/GonzalezJ05M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Bach/Fugue/bwv_868/GonzalezJ05M_note_alignments/parangonada_data/part.csv
# ...
#   inflating: asap-dataset-note_alignments/Schumann/Toccata_repeat/Zhdanov06_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Schumann/Toccata_repeat/Zhdanov06_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Schumann/Toccata_repeat/Zhdanov06_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Schumann/Toccata_repeat/Zhdanov06_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Schumann/Toccata_repeat/Zhdanov06_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Schumann/Toccata_repeat/midi_score.mid
#   inflating: asap-dataset-note_alignments/Schumann/Toccata_repeat/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Schumann/Toccata_repeat/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Scriabin/
#    creating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/
#    creating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi03_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/Shi08M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/YeF09_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/midi_score.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Scriabin/Etudes_op_8/11/xml_score.musicxml
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/ChernovA06M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FALIKS06_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/FaB05M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/GarritsonL06M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Ko07M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na03_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Na07M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/TET02_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy02_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M_annotations.txt
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M_note_alignments/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M_note_alignments/note_alignment.tsv
#    creating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M_note_alignments/parangonada_data/
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M_note_alignments/parangonada_data/align.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M_note_alignments/parangonada_data/feature.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M_note_alignments/parangonada_data/part.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M_note_alignments/parangonada_data/ppart.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/Yeletskiy07M_note_alignments/parangonada_data/zalign.csv
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/midi_score.mid
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/midi_score_annotations.txt
#   inflating: asap-dataset-note_alignments/Scriabin/Sonatas/5/xml_score.musicxml
#   inflating: asap-dataset-note_alignments/asap_annotations.json
#   inflating: asap-dataset-note_alignments/environment.yml
#   inflating: asap-dataset-note_alignments/initialize_dataset.py
#   inflating: asap-dataset-note_alignments/metadata.csv
#    creating: asap-dataset-note_alignments/util/
#   inflating: asap-dataset-note_alignments/util/MIDIToMIDIAlign.sh
#   inflating: asap-dataset-note_alignments/util/check_dataset_quality.ipynb
#   inflating: asap-dataset-note_alignments/util/create_json.ipynb
#   inflating: asap-dataset-note_alignments/util/full_ann_pipeline.ipynb
#   inflating: asap-dataset-note_alignments/util/usage_example.ipynb
#   inflating: asap-dataset-note_alignments/util/util.py

# %%
files = [(os.path.join(root, file), os.path.join(os.path.dirname(root), os.path.basename(root).split("_")[0]+".mid"),os.path.join(os.path.dirname(root), "xml_score.musicxml"), os.path.join(root, os.path.splitext(file)[0]+".match")) for root, dirs, files in os.walk("asap-dataset-note_alignments") for file in files if file.endswith("note_alignment.tsv")]

# %%
def produce_match(alignment_fn, mfn, sfn, match_name):
	"""
	Produce and Save Match.

	Parameters
	----------
	mfn : str
		Performance Midi File Path
	sfn : str
		Score musicxml File Path
	alignment_fn : str
		Alignment ".txt" file path
	match_name : str
		Path and Save Name.
	"""
	data = pd.read_csv(alignment_fn, sep="\t")

	alignment = list()
	for x in data[["xml_id", "midi_id"]].to_numpy():
		if x[1] == "deletion":
			dd = dict(label="deletion", score_id=x[0])
		# TODO for asap alignments to contain "n"
		elif x[0] == "insertion":
			dd = dict(label="insertion", performance_id=str(x[1]))
		else:
			dd = dict(label="match", score_id=x[0], performance_id=str(x[1]))
		alignment.append(dd)
	ppart = pt.load_performance_midi(mfn)
	# This may cause re-indexing.
	spart = pt.score.merge_parts(pt.load_musicxml(sfn))
	spart = pt.score.unfold_part_maximal(spart, ignore_leaps=False)
	pt.save_match(alignment, ppart, spart, match_name)

# %%
for (afn, mfn, sfn, match_name) in files:
    produce_match(afn, mfn, sfn, match_name)
# Out:
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n625 end=n630 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n922 end=n929 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n572 end=n579 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n798 end=n805 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n1 end=n8 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n51 end=n58 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n109 end=n116 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n572 end=n579 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n109 end=n116 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n625 end=n630 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n1 end=n8 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n400 end=n407 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n798 end=n805 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1204 Slur start=n1084 end=n1085 start=None end=TimePoint t=1204 quarter=8, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1204 Slur start=n1086 end=n1087 start=None end=TimePoint t=1204 quarter=8, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1204 Slur start=n1086 end=n1087 start=None end=TimePoint t=1204 quarter=8, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1204 Slur start=n1084 end=n1085 start=None end=TimePoint t=1204 quarter=8, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1204 Slur start=n1086 end=n1087 start=None end=TimePoint t=1204 quarter=8, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n391 end=n393 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n288 end=n290 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n394 end=n396 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n388 end=n390 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n380 end=n382 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n371 end=n373 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n377 end=n379 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n129 end=n131 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n282 end=n284 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n135 end=n137 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n297 end=n299 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n300 end=n302 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n256 end=n258 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n495 end=n497 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n273 end=n275 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n285 end=n287 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n250 end=n252 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n132 end=n134 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n244 end=n246 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n270 end=n272 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n247 end=n249 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n498 end=n500 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n279 end=n281 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=r8 end=n470 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n253 end=n255 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n474 end=n476 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n501 end=n503 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n480 end=n482 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n234 end=n236 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n655 end=n657 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n652 end=n654 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n610 end=n612 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n613 end=n615 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n90 end=n92 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n640 end=n642 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n99 end=n101 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n646 end=n648 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n768 end=n770 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n628 end=n630 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n643 end=n645 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n588 end=n590 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n585 end=n587 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n622 end=n624 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4 end=n6 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n649 end=n651 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n795 end=n797 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n619 end=n621 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n27 end=n29 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n798 end=n800 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n781 end=n783 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n605 end=n607 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n765 end=n767 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n625 end=n627 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n774 end=n776 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n559 end=n561 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n792 end=n794 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n595 end=n597 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n602 end=n604 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n545 end=n547 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n539 end=n541 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n592 end=n594 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n508 end=n510 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n96 end=n98 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n556 end=n558 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n533 end=n535 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n542 end=n544 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n771 end=n773 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n777 end=n779 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n1 end=n3 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n756 end=n758 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n521 end=n523 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n513 end=n515 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n30 end=n32 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n518 end=n520 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n548 end=n550 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n87 end=n89 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n572 end=n574 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n84 end=n86 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n93 end=n95 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=r10 end=n512 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n10 end=n12 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n548 end=n550 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n542 end=n544 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n545 end=n547 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n297 end=n299 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n575 end=n577 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n521 end=n523 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n539 end=n541 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n605 end=n607 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n559 end=n561 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n562 end=n564 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n279 end=n281 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n572 end=n574 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n270 end=n272 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n595 end=n597 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n253 end=n255 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n282 end=n284 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n592 end=n594 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n610 end=n612 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n613 end=n615 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n628 end=n630 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n513 end=n515 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n474 end=n476 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n533 end=n535 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n553 end=n555 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n536 end=n538 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n285 end=n287 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n556 end=n558 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n391 end=n393 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n247 end=n249 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n264 end=n266 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n640 end=n642 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n501 end=n503 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n649 end=n651 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=r10 end=n512 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n646 end=n648 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n619 end=n621 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n622 end=n624 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n655 end=n657 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n300 end=n302 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n377 end=n379 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n508 end=n510 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n498 end=n500 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n588 end=n590 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n652 end=n654 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n241 end=n243 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n267 end=n269 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n518 end=n520 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n273 end=n275 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=r9 end=n507 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n483 end=n485 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n380 end=n382 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n385 end=n387 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n250 end=n252 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n371 end=n373 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n495 end=n497 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n768 end=n770 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n36 end=n38 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n771 end=n773 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n138 end=n140 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n96 end=n98 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n87 end=n89 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n81 end=n83 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n789 end=n791 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n792 end=n794 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n774 end=n776 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n777 end=n779 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n102 end=n104 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
# ...
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3646 end=n3648 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3649 end=n3651 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3652 end=n3654 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1462272 Slur start=n3640 end=n3657 start=None end=TimePoint t=1462272 quarter=7168, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3655 end=n3657 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4878 end=n4893 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4938 end=n4953 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3683 end=n3685 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3686 end=n3688 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3689 end=n3691 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4894 end=n4909 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3692 end=n3694 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4954 end=n4969 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3695 end=n3697 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1487360 Slur start=n3640 end=n3679 start=None end=TimePoint t=1487360 quarter=7168, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1487360 Slur start=n3683 end=n3700 start=None end=TimePoint t=1487360 quarter=7168, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3698 end=n3700 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --2175488 Slur start=n4938 end=n4975 start=None end=TimePoint t=2175488 quarter=7168, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4970 end=n4975 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3725 end=n3727 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3728 end=n3731 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4918 end=n4933 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3732 end=n3734 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3735 end=n3738 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3739 end=n3741 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3742 end=n3745 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4977 end=n4992 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3770 end=n3772 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1516032 Slur start=n3770 end=n3775 start=None end=TimePoint t=1516032 quarter=7168, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3773 end=n3775 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4993 end=n5008 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3776 end=n3780 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n3781 end=n3783 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4269 end=n4308 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4309 end=n4321 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4322 end=n4334 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4335 end=n4341 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4344 end=n4362 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4363 end=n4377 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1770496 Slur start=n4363 end=n4378 start=None end=TimePoint t=1770496 quarter=7168, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4399 end=n4401 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4379 end=n4381 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4382 end=n4384 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4385 end=n4387 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4388 end=n4390 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4391 end=n4393 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4394 end=n4396 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n4414 end=n4425 start=None end=None, substituting None
#
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [17], line 2
#       1 for (afn, mfn, sfn, match_name) in files:
# ----> 2     produce_match(afn, mfn, sfn, match_name)
#
# Cell In [13], line 32, in produce_match(alignment_fn, mfn, sfn, match_name)
#      30 spart = pt.score.merge_parts(pt.load_musicxml(sfn))
#      31 spart = pt.score.unfold_part_maximal(spart, ignore_leaps=False)
# ---> 32 pt.save_match(alignment, ppart, spart, match_name)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/misc.py:49, in deprecated_alias.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#      46 @functools.wraps(f)
#      47 def wrapper(*args, **kwargs):
#      48     rename_kwargs(f.__name__, kwargs, aliases)
# ---> 49     return f(*args, **kwargs)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/exportmatch.py:385, in save_match(alignment, performance_data, score_data, out, mpq, ppq, performer, composer, piece)
#     379     raise ValueError(
#     380         "`performance_data` should be a `Performance`, a `PerformedPart`, or a "
#     381         f"list of `PerformedPart` objects, but is {type(score_data)}"
#     382     )
#     384 # Get matchfile
# --> 385 matchfile = matchfile_from_alignment(
#     386     alignment=alignment,
#     387     ppart=ppart,
#     388     spart=spart,
#     389     mpq=mpq,
#     390     ppq=ppq,
#     391     performer=performer,
#     392     composer=composer,
#     393     piece=piece,
#     394 )
#     396 if out is not None:
#     397     # write matchfile
#     398     matchfile.write(out)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/exportmatch.py:131, in matchfile_from_alignment(alignment, ppart, spart, mpq, ppq, performer, composer, piece, magaloff_zeilinger_quirk)
#     122 # Measure map (which measure corresponds to each timepoint
#     123 measure_starts = np.array(
#     124     [(m.number, m.start.t) for m in spart.iter_all(score.Measure)]
#     125 )
#     126 measure_map = interp1d(
#     127     measure_starts[:, 1],
#     128     measure_starts[:, 0],
#     129     kind="previous",
#     130     bounds_error=False,
# --> 131     fill_value=(measure_starts[:, 0].min(), measure_starts[:, 0].max()),
#     132 )
#     134 # Create MatchSnotes from score information
#     135 score_info = dict()
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/numpy/core/_methods.py:44, in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'

# %%
def tokenize_pitch_spelling(ps_note):
	step = {"A": 0, "B": 1, "C": 2, "D": 3, "E": 4, "F": 5, "G": 6}[ps_note["step"].item()]
	return step, ps_note["alter"], ps_note["octave"]

def create_data():
	_, _, _, match_files = zip(*files)
	data = list()
	labels = list()
	for match_file in match_files:
		performance, alignment, score = pt.load_match(match_file, create_score=True)
		matched_notes = [alignment[idx] for idx, d in enumerate(alignment) if d["label"] == "match"]
		pna = performance.note_array()
		sna = score.note_array(include_pitch_spelling=True)
		X, y = np.zeros((len(matched_notes), 3), dtype=float), np.zeros((len(matched_notes), 3), dtype=int)
		for idx, match_note in enumerate(matched_notes):
			X[idx] = np.lib.recfunctions.structured_to_unstructured(pna[np.where(pna["id"] == match_note["performance_id"])][["onset_sec", "duration_sec", "pitch"]])
			y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
		data.append(X)
		labels.append(y)
	return data, labels
# Out:
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# ...
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
# /tmp/ipykernel_451760/4184092116.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])

# %%
# Out:
# array([[2, 1, 5],
#        [3, 1, 5],
#        [4, 1, 5],
#        ...,
#        [5, 1, 2],
#        [0, 1, 4],
#        [5, 1, 5]])

# %% [markdown]
# # Voice Separation
