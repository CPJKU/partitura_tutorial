# %%
import partitura as pt
import torch
import torch.nn as nn
from torch.nn import functional as F
import numpy as np
import os
import pandas as pd
import pytorch_lightning as pl
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# # Pitch Spelling with Partitura
#
# Have you always been bad at spelling bee, do you find that spelling notes makes this even worse. Your time of struggling is over.... Today we going to teach a Model to learn how to *pitch* spell.
#
# ### Definition
#
# Spelling a pitch relates to the system of naming notes by letters (A-G) and sharp(#) and flat (♭) signs - and sometimes double sharp and flat signs, resulting in names or 'spellings' like 'A♭', 'D#', 'F♭♭'.
#
# Translating between frequencies in Hz and such names is non-trivial. You need to consider :
#
# -  The 'concert pitch' you are taking as a reference
# - The temperament in which the piece is played
# - The overall key that the music would be notated in
# - Use of the correct enharmonic equivalents for accidentals (Using the correct enharmonic equivalent, Purpose of double-sharps and double-flats?)
#
# If translating between, say, MIDI note numbers and 'spelled' names, the first two steps can be skipped.
#
# Spelled pitch names often have an octave number appended for disambiguation - e.g. 'A♭3', 'D#5'.
#
#
# ### Some Spelling algorithms
#
# Partitura contains an implementation for a standard algorithm for Pitch Spelling. The algorithm in question is called ps13 created by Meredith and al.:
#
# 	The ps13 pitch spelling algorithm, D Meredith - Journal of New Music Research, 2006
#
# Some notable algorithms and currect SOTA is PKSpell.
#
# 	PKSpell: Data-driven pitch spelling and key signature estimation
# 	F Foscarin, N Audebert, R Fournier-S'Niehotta, 2021
#
#
# Let's first download a pitch spelling dataset.

# %%
# !wget https://github.com/CPJKU/vienna4x22/archive/refs/heads/master.zip
# Out:
# --2022-10-31 10:47:16--  https://github.com/CPJKU/vienna4x22/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/CPJKU/vienna4x22/zip/refs/heads/master [following]
# --2022-10-31 10:47:22--  https://codeload.github.com/CPJKU/vienna4x22/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [                <=> ]   6.33M  1.84MB/s    in 3.6s
#
# 2022-10-31 10:47:27 (1.75 MB/s) - ‘master.zip’ saved [6636510]

# %%
# !unzip ./master.zip
# Out:
# Archive:  ./master.zip
# b2c0d7a29c236724868efba005db290c6bc01704
#    creating: vienna4x22-master/
#  extracting: vienna4x22-master/.gitignore
#   inflating: vienna4x22-master/README.md
#    creating: vienna4x22-master/match/
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p01.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p02.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p03.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p04.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p05.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p06.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p07.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p08.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p09.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p10.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p11.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p12.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p13.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p14.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p15.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p16.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p17.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p18.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p19.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p20.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p21.match
#   inflating: vienna4x22-master/match/Chopin_op10_no3_p22.match
#   inflating: vienna4x22-master/match/Chopin_op38_p01.match
#   inflating: vienna4x22-master/match/Chopin_op38_p02.match
#   inflating: vienna4x22-master/match/Chopin_op38_p03.match
#   inflating: vienna4x22-master/match/Chopin_op38_p04.match
#   inflating: vienna4x22-master/match/Chopin_op38_p05.match
#   inflating: vienna4x22-master/match/Chopin_op38_p06.match
#   inflating: vienna4x22-master/match/Chopin_op38_p07.match
#   inflating: vienna4x22-master/match/Chopin_op38_p08.match
#   inflating: vienna4x22-master/match/Chopin_op38_p09.match
#   inflating: vienna4x22-master/match/Chopin_op38_p10.match
#   inflating: vienna4x22-master/match/Chopin_op38_p11.match
#   inflating: vienna4x22-master/match/Chopin_op38_p12.match
#   inflating: vienna4x22-master/match/Chopin_op38_p13.match
#   inflating: vienna4x22-master/match/Chopin_op38_p14.match
#   inflating: vienna4x22-master/match/Chopin_op38_p15.match
#   inflating: vienna4x22-master/match/Chopin_op38_p16.match
#   inflating: vienna4x22-master/match/Chopin_op38_p17.match
#   inflating: vienna4x22-master/match/Chopin_op38_p18.match
#   inflating: vienna4x22-master/match/Chopin_op38_p19.match
#   inflating: vienna4x22-master/match/Chopin_op38_p20.match
#   inflating: vienna4x22-master/match/Chopin_op38_p21.match
#   inflating: vienna4x22-master/match/Chopin_op38_p22.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p01.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p02.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p03.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p04.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p05.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p06.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p07.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p08.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p09.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p10.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p11.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p12.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p13.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p14.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p15.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p16.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p17.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p18.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p19.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p20.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p21.match
#   inflating: vienna4x22-master/match/Mozart_K331_1st-mov_p22.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p01.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p02.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p03.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p04.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p05.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p06.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p07.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p08.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p09.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p10.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p11.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p12.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p13.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p14.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p15.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p16.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p17.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p18.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p19.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p20.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p21.match
#   inflating: vienna4x22-master/match/Schubert_D783_no15_p22.match
#    creating: vienna4x22-master/midi/
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p01.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p02.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p03.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p04.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p05.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p06.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p07.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p08.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p09.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p10.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p11.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p12.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p13.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p14.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p15.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p16.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p17.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p18.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p19.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p20.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p21.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p22.mid
#   inflating: vienna4x22-master/midi/Chopin_op10_no3_p23-average.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p01.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p02.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p03.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p04.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p05.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p06.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p07.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p08.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p09.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p10.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p11.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p12.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p13.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p14.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p15.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p16.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p17.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p18.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p19.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p20.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p21.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_1st-3rd_p22.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p01.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p02.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p03.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p04.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p05.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p06.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p07.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p08.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p09.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p10.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p11.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p12.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p13.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p14.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p15.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p16.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p17.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p18.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p19.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p20.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p21.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p22.mid
#   inflating: vienna4x22-master/midi/Chopin_op38_p23-average.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p01.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p02.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p03.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p04.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p05.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p06.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p07.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p08.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p09.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p10.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p11.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p12.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p13.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p14.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p15.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p16.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p17.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p18.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p19.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p20.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p21.mid
#   inflating: vienna4x22-master/midi/Mozart_K331_1st-mov_p22.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p01.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p02.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p03.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p04.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p05.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p06.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p07.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p08.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p09.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p10.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p11.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p12.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p13.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p14.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p15.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p16.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p17.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p18.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p19.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p20.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p21.mid
#   inflating: vienna4x22-master/midi/Schubert_D783_no15_p22.mid
#    creating: vienna4x22-master/musicxml/
#   inflating: vienna4x22-master/musicxml/Chopin_op10_no3.musicxml
#   inflating: vienna4x22-master/musicxml/Chopin_op38.musicxml
#   inflating: vienna4x22-master/musicxml/Mozart_K331_1st-mov.musicxml
#   inflating: vienna4x22-master/musicxml/Schubert_D783_no15.musicxml
#   inflating: vienna4x22-master/musicxml/fix_xml_note_attribute_order.py
#   inflating: vienna4x22-master/musicxml/move_stem.sh
#    creating: vienna4x22-master/pdf/
#   inflating: vienna4x22-master/pdf/Chopin_op10_no3.pdf
#   inflating: vienna4x22-master/pdf/Chopin_op38.pdf
#   inflating: vienna4x22-master/pdf/Mozart_K331_1st-mov.pdf
#   inflating: vienna4x22-master/pdf/Schubert_D783_no15.pdf
#    creating: vienna4x22-master/png/
#   inflating: vienna4x22-master/png/Chopin_op10_no3.png
#   inflating: vienna4x22-master/png/Chopin_op38.png
#   inflating: vienna4x22-master/png/Mozart_K331_1st-mov.png
#   inflating: vienna4x22-master/png/Schubert_D783_no15.png

# %%
files = [(os.path.join(root, file), os.path.join(os.path.dirname(root), "musicxml", file[:-10]+".musicxml")) for root, dirs, files in os.walk("vienna4x22-master") for file in files if file.endswith(".match")]

# %%
files[0]
# Out:
# ('vienna4x22-master/match/Chopin_op10_no3_p14.match',
#  'vienna4x22-master/musicxml/Chopin_op10_no3.musicxml')

# %%
def produce_match(alignment_fn, mfn, sfn, match_name):
	"""
	Produce and Save Match.

	Parameters
	----------
	mfn : str
		Performance Midi File Path
	sfn : str
		Score musicxml File Path
	alignment_fn : str
		Alignment ".txt" file path
	match_name : str
		Path and Save Name.
	"""
	data = pd.read_csv(alignment_fn, sep="\t")

	alignment = list()
	for x in data[["xml_id", "midi_id"]].to_numpy():
		if x[1] == "deletion":
			dd = dict(label="deletion", score_id=x[0])
		# TODO for asap alignments to contain "n"
		elif x[0] == "insertion":
			dd = dict(label="insertion", performance_id=str(x[1]))
		else:
			dd = dict(label="match", score_id=x[0], performance_id=str(x[1]))
		alignment.append(dd)
	ppart = pt.load_performance_midi(mfn)
	# This may cause re-indexing.
	spart = pt.score.merge_parts(pt.load_musicxml(sfn))
	spart = pt.score.unfold_part_maximal(spart, ignore_leaps=False)
	pt.save_match(alignment, ppart, spart, match_name)

# %%
for (afn, mfn, sfn, match_name) in files:
	try:
		produce_match(afn, mfn, sfn, match_name)
	except Exception as e:
		print("Match creation of file {} failed with {}".format(match_name, e))
# Out:
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n1 end=n8 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n51 end=n58 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n109 end=n116 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n572 end=n579 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n798 end=n805 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n400 end=n407 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n625 end=n630 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n922 end=n929 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n798 end=n805 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n1 end=n8 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n51 end=n58 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n922 end=n929 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n109 end=n116 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n572 end=n579 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n400 end=n407 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n625 end=n630 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1204 Slur start=n1084 end=n1085 start=None end=TimePoint t=1204 quarter=8, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1204 Slur start=n1086 end=n1087 start=None end=TimePoint t=1204 quarter=8, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1204 Slur start=n1084 end=n1085 start=None end=TimePoint t=1204 quarter=8, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1204 Slur start=n1086 end=n1087 start=None end=TimePoint t=1204 quarter=8, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "(   )" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n394 end=n396 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n391 end=n393 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n374 end=n376 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n380 end=n382 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n388 end=n390 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n288 end=n290 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n282 end=n284 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n297 end=n299 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n129 end=n131 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n495 end=n497 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n474 end=n476 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n777 end=n779 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n548 end=n550 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n81 end=n83 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n477 end=n479 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n90 end=n92 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n768 end=n770 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n756 end=n758 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n792 end=n794 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n536 end=n538 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n795 end=n797 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n99 end=n101 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n784 end=n786 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=r9 end=n507 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n762 end=n764 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n542 end=n544 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n84 end=n86 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n483 end=n485 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n7 end=n9 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n774 end=n776 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=r10 end=n512 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n628 end=n630 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n96 end=n98 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n521 end=n523 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n781 end=n783 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n602 end=n604 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n518 end=n520 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n643 end=n645 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n270 end=n272 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n36 end=n38 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=r8 end=n470 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n652 end=n654 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n247 end=n249 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n572 end=n574 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n267 end=n269 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n513 end=n515 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n539 end=n541 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n508 end=n510 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n649 end=n651 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n234 end=n236 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n588 end=n590 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n655 end=n657 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n33 end=n35 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n501 end=n503 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n765 end=n767 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n231 end=n233 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n556 end=n558 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n605 end=n607 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n625 end=n627 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n646 end=n648 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n244 end=n246 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n798 end=n800 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n619 end=n621 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n622 end=n624 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n30 end=n32 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n27 end=n29 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n610 end=n612 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n595 end=n597 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n640 end=n642 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n279 end=n281 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n241 end=n243 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n264 end=n266 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n771 end=n773 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n99 end=n101 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n613 end=n615 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n655 end=n657 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n93 end=n95 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n640 end=n642 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n471 end=n473 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n789 end=n791 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n508 end=n510 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n605 end=n607 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n619 end=n621 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n646 end=n648 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n480 end=n482 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=r10 end=n512 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n495 end=n497 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n96 end=n98 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n501 end=n503 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n90 end=n92 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n533 end=n535 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n592 end=n594 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n643 end=n645 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n492 end=n494 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n610 end=n612 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n483 end=n485 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n498 end=n500 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n622 end=n624 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n138 end=n140 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n132 end=n134 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n628 end=n630 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n652 end=n654 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n548 end=n550 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=r8 end=n470 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n234 end=n236 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n542 end=n544 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n575 end=n577 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n556 end=n558 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n87 end=n89 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n536 end=n538 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n572 end=n574 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n102 end=n104 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n539 end=n541 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n625 end=n627 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n559 end=n561 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n474 end=n476 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n135 end=n137 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n518 end=n520 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n84 end=n86 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n7 end=n9 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n774 end=n776 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n792 end=n794 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n297 end=n299 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n756 end=n758 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n256 end=n258 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n241 end=n243 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n279 end=n281 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n244 end=n246 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n759 end=n761 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n273 end=n275 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n391 end=n393 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n250 end=n252 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n270 end=n272 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n282 end=n284 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n388 end=n390 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n380 end=n382 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n33 end=n35 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n762 end=n764 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n36 end=n38 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n253 end=n255 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n27 end=n29 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# ...
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 512821  and resulting seconds per tick = 0.0010683770833333334at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 512821  and resulting seconds per tick = 0.0010683770833333334at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1728 Slur start=n788 end=n789 start=None end=TimePoint t=1728 quarter=16, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 512821  and resulting seconds per tick = 0.0010683770833333334at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 512821  and resulting seconds per tick = 0.0010683770833333334at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 512821  and resulting seconds per tick = 0.0010683770833333334at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 512821  and resulting seconds per tick = 0.0010683770833333334at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 512821  and resulting seconds per tick = 0.0010683770833333334at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n92 end=n98 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n195 end=n201 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n167 end=n173 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n181 end=n187 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0010416666666666667at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n92 end=n98 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n195 end=n201 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: -- Tuplet start=n167 end=n173 start=None end=None, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --406 Slur start=n362 end=n363 start=None end=TimePoint t=406 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --414 Slur start=n365 end=n366 start=None end=TimePoint t=414 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --430 Slur start=n383 end=n384 start=None end=TimePoint t=430 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --504 Slur start=n460 end=n461 start=None end=TimePoint t=504 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --984 Slur start=n876 end=n877 start=None end=TimePoint t=984 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --1000 Slur start=n890 end=n891 start=None end=TimePoint t=1000 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --870 Slur start=n765 end=n767 start=None end=TimePoint t=870 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --904 Slur start=n805 end=n806 start=None end=TimePoint t=904 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --920 Slur start=n816 end=n819 start=None end=TimePoint t=920 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --928 Slur start=n820 end=n823 start=None end=TimePoint t=928 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/utils/generic.py:235: UserWarning: reference not found in
#                             o_map: --120 Slur start=n101 end=n102 start=None end=TimePoint t=120 quarter=4, substituting None
#
#   warnings.warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmidi.py:140: UserWarning: change of Tempo to mpq = 500000  and resulting seconds per tick = 0.0013020833333333333at time: 0.0
#   warnings.warn(
#
# KeyboardInterrupt

# %%
def tokenize_pitch_spelling(ps_note):
	step = {"A": 0, "B": 1, "C": 2, "D": 3, "E": 4, "F": 5, "G": 6}[ps_note["step"].item()]
	return [step, ps_note["alter"].item(), ps_note["octave"].item()]

def create_data(files):
	X_train = list()
	y_train = list()
	X_test = list()
	y_test = list()
	for match_file, score_file in files:
		performance, alignment = pt.load_match(match_file)
		score = pt.load_score(score_file)
		matched_notes = [alignment[idx] for idx, d in enumerate(alignment) if d["label"] == "match"]
		pna = performance.note_array()
		sna = score.note_array(include_pitch_spelling=True)
		X, y = np.zeros((len(matched_notes), 3), dtype=float), np.zeros((len(matched_notes), 3), dtype=int)
		for idx, match_note in enumerate(matched_notes):
			X[idx] = np.lib.recfunctions.structured_to_unstructured(pna[np.where(pna["id"] == str(match_note["performance_id"]))][["onset_sec", "duration_sec", "pitch"]])
			y[idx] = tokenize_pitch_spelling(sna[np.where(sna["id"] == match_note["score_id"])][["step", "alter", "octave"]])
		if os.path.basename(match_file).startswith("Mozart"):
			X_test.append(X)
			y_test.append(y)
		else:
			X_train.append(X)
			y_train.append(y)
	return X_train, y_train, X_test, y_test

# %%
X_train, y_train, X_test, y_test = create_data(files)
# Out:
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# Exception in thread Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/multiprocessing/queues.py", line 239, in _feed
# QueueFeederThread:
# Traceback (most recent call last):
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/multiprocessing/queues.py", line 239, in _feed
#     reader_close()
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/multiprocessing/connection.py", line 182, in close
#     self._close()
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/multiprocessing/connection.py", line 366, in _close
#     reader_close()
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/multiprocessing/connection.py", line 182, in close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self._close()
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/multiprocessing/connection.py", line 366, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/threading.py", line 953, in run
#     self.run()
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/multiprocessing/queues.py", line 271, in _feed
#     queue_sem.release()
# ValueError: semaphore or lock released too many times
#     self._target(*self._args, **self._kwargs)
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/multiprocessing/queues.py", line 271, in _feed
#     queue_sem.release()
# ValueError: semaphore or lock released too many times
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/io/importmusicxml.py:1338: UserWarning: Dropping slur 3 starting at 2592 (n120-2) and ending at 1696 (n126-1)
#   warnings.warn(msg)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/partitura/directions.py:533: UserWarning: error parsing "ritenuto" (UnexpectedCharacters)
#   warnings.warn('error parsing "{}" ({})'.format(string, type(e).__name__))

# %% [markdown]
# ### Model

# %%
PAD = "<PAD>"

PITCHES = {
	0: ["C", "B#", "D--"],
	1: ["C#", "B##", "D-"],
	2: ["D", "C##", "E--"],
	3: ["D#", "E-", "F--"],
	4: ["E", "D##", "F-"],
	5: ["F", "E#", "G--"],
	6: ["F#", "E##", "G-"],
	7: ["G", "F##", "A--"],
	8: ["G#", "A-"],
	9: ["A", "G##", "B--"],
	10: ["A#", "B-", "C--"],
	11: ["B", "A##", "C-"],
}

INTERVALS = {
	0: ["P1", "d2", "A7"],
	1: ["m2", "A1"],
	2: ["M2", "d3", "AA1"],
	3: ["m3", "A2"],
	4: ["M3", "d4", "AA2"],
	5: ["P4", "A3"],
	6: ["d5", "A4"],
	7: ["P5", "d6", "AA4"],
	8: ["m6", "A5"],
	9: ["M6", "d7", "AA5"],
	10: ["m7", "A6"],
	11: ["M7", "d1", "AA6"],
}

DIATONIC_PITCHES = ["C", "D", "E", "F", "G", "A", "B"]

KEY_SIGNATURES = list(range(-7, 8))
accepted_pitches = [ii for i in PITCHES.values() for ii in i]
accepted_ks = KEY_SIGNATURES
pitch_to_ix = {p: accepted_pitches.index(p) for p in accepted_pitches}
ks_to_ix = {k: KEY_SIGNATURES.index(k) for k in KEY_SIGNATURES}
# add PADDING TAD
pitch_to_ix[PAD] = len(accepted_pitches)
ks_to_ix[PAD] = len(KEY_SIGNATURES)

# %%
class PKSpell(nn.Module):
	"""Models that decouples key signature estimation from pitch spelling by adding a second RNN.
	This model reached state of the art performances for pitch spelling.
	"""

	def __init__(
		self,
		input_dim=3,
		hidden_dim=100,
		pitch_to_ix=pitch_to_ix,
		hidden_dim2=24,
		rnn_depth=1,
		dropout=0.1,
		bidirectional=True
	):
		super(PKSpell, self).__init__()
		self.dropout = nn.Dropout(dropout)
		self.n_out_pitch = len(pitch_to_ix)
		self.hidden_dim = hidden_dim
		self.hidden_dim2 = hidden_dim2

		# RNN layer.
		self.rnn = nn.LSTM(
			input_size=input_dim,
			hidden_size=hidden_dim // 2 if bidirectional else hidden_dim,
			bidirectional=bidirectional,
			num_layers=rnn_depth,
		)
		# Output layers.
		self.top_layer_pitch = nn.Linear(hidden_dim, self.n_out_pitch)
		# Loss function that we will use during training.
		self.loss_pitch = nn.CrossEntropyLoss(
			reduction="mean", ignore_index=pitch_to_ix[PAD]
		)

	def compute_outputs(self, sentences, sentences_len):
		sentences = nn.utils.rnn.pack_padded_sequence(sentences, sentences_len)
		rnn_out, _ = self.rnn(sentences)
		rnn_out, _ = nn.utils.rnn.pad_packed_sequence(rnn_out)
		if self.dropout is not None:
			rnn_out = self.dropout(rnn_out)
		out_pitch = self.top_layer_pitch(rnn_out)
		return out_pitch

	def forward(self, sentences, pitches, sentences_len):
		# First computes the predictions, and then the loss function.

		# Compute the outputs. The shape is (max_len, n_sentences, n_labels).
		scores_pitch = self.compute_outputs(sentences, sentences_len)

		# Flatten the outputs and the gold-standard labels, to compute the loss.
		# The input to this loss needs to be one 2-dimensional and one 1-dimensional tensor.
		scores_pitch = scores_pitch.view(-1, self.n_out_pitch)
		pitches = pitches.view(-1)
		loss = self.loss_pitch(scores_pitch, pitches)
		return loss

	def predict(self, sentences, sentences_len):
		# Compute the outputs from the linear units.
		scores_pitch, scores_ks = self.compute_outputs(sentences, sentences_len)

		# Select the top-scoring labels. The shape is now (max_len, n_sentences).
		predicted_pitch = scores_pitch.argmax(dim=2)
		return [predicted_pitch[: int(l), i].cpu().numpy() for i, l in enumerate(sentences_len)]


class PSDataset(Dataset):
	def __init__(self, x, y):
		super(PSDataset, self).__init__()
		self.x = x
		self.y = y
	def __getitem__(self, idx):
		return torch.tensor(self.x[idx]), torch.tensor(self.y[idx])
	def __len__(self):
		return len(self.x)

def collate_ps(data):
	def merge(sequences):
		lengths = [len(seq) for seq in sequences]
		padded_seqs = torch.zeros(len(sequences), max(lengths)).long()
		for i, seq in enumerate(sequences):
			end = lengths[i]
			padded_seqs[i, :end] = seq[:end]
		return padded_seqs, lengths

	# sort a list by sequence length (descending order) to use pack_padded_sequence
	data.sort(key=lambda x: len(x[0]), reverse=True)

	# seperate source and target sequences
	src_seqs, trg_seqs = zip(*data)

	# merge sequences (from tuple of 1D tensor to 2D tensor)
	src_seqs, src_lengths = merge(src_seqs)
	trg_seqs, trg_lengths = merge(trg_seqs)

	return src_seqs, src_lengths, trg_seqs

class PKSpellPL(pl.LightningModule):
	def __init__(self):
		super(PKSpellPL, self).__init__()
		self.module = PKSpell()
	def training_step(self, batch, batch_idx):
		src_seqs, src_lengths, trg_seqs = batch
		loss = self.module(src_seqs, src_lengths, trg_seqs)
		self.log("train_loss", loss.item(), on_epoch=True)
		return loss
	def val_step(self, batch, batch_idx):
		src_seqs, src_lengths, trg_seqs = batch
		loss = self.module(src_seqs, src_lengths, trg_seqs)
		self.log("val_loss", loss.item(), on_epoch=True)
		return loss
	def configure_optimizers(self):
		optimizer = torch.optim.Adam(self.parameters(), lr=0.001, weight_decay=5e-4)
		return {
			"optimizer": optimizer,
		}

# %% [markdown]
# ### Train the PKSpell model

# %%
model = PKSpellPL()
train_dataloader = DataLoader(PSDataset(X_train, y_train), collate_fn=collate_ps, batch_size=3, num_workers=2)
val_dataloader = DataLoader(PSDataset(X_test, y_test), collate_fn=collate_ps, batch_size=3, num_workers=2)
trainer = pl.Trainer()
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model, train_dataloader, val_dataloader)
# Out:
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/loops/utilities.py:89: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   rank_zero_warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:105: UserWarning: You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.
#   rank_zero_warn("You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.")
# Missing logger folder: /home/manos/Desktop/JKU/codes/partitura_tutorial/content/lightning_logs
#
#   | Name   | Type    | Params
# -----------------------------------
# 0 | module | PKSpell | 25.6 K
# -----------------------------------
# 25.6 K    Trainable params
# 0         Non-trainable params
# 25.6 K    Total params
# 0.103     Total estimated model params size (MB)
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:236: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:1892: PossibleUserWarning: The number of training batches (22) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [50], line 1
# ----> 1 trainer.fit(model, train_dataloader, val_dataloader)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:696, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     677 r"""
#     678 Runs the full optimization routine.
#     679
#    (...)
#     693     datamodule: An instance of :class:`~pytorch_lightning.core.datamodule.LightningDataModule`.
#     694 """
#     695 self.strategy.model = model
# --> 696 self._call_and_handle_interrupt(
#     697     self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     698 )
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:650, in Trainer._call_and_handle_interrupt(self, trainer_fn, *args, **kwargs)
#     648         return self.strategy.launcher.launch(trainer_fn, *args, trainer=self, **kwargs)
#     649     else:
# --> 650         return trainer_fn(*args, **kwargs)
#     651 # TODO(awaelchli): Unify both exceptions below, where `KeyboardError` doesn't re-raise
#     652 except KeyboardInterrupt as exception:
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:735, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     731 ckpt_path = ckpt_path or self.resume_from_checkpoint
#     732 self._ckpt_path = self.__set_ckpt_path(
#     733     ckpt_path, model_provided=True, model_connected=self.lightning_module is not None
#     734 )
# --> 735 results = self._run(model, ckpt_path=self.ckpt_path)
#     737 assert self.state.stopped
#     738 self.training = False
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:1166, in Trainer._run(self, model, ckpt_path)
#    1162 self._checkpoint_connector.restore_training_state()
#    1164 self._checkpoint_connector.resume_end()
# -> 1166 results = self._run_stage()
#    1168 log.detail(f"{self.__class__.__name__}: trainer tearing down")
#    1169 self._teardown()
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:1252, in Trainer._run_stage(self)
#    1250 if self.predicting:
#    1251     return self._run_predict()
# -> 1252 return self._run_train()
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:1283, in Trainer._run_train(self)
#    1280 self.fit_loop.trainer = self
#    1282 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1283     self.fit_loop.run()
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/loops/loop.py:200, in Loop.run(self, *args, **kwargs)
#     198 try:
#     199     self.on_advance_start(*args, **kwargs)
# --> 200     self.advance(*args, **kwargs)
#     201     self.on_advance_end()
#     202     self._restarting = False
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:271, in FitLoop.advance(self)
#     267 self._data_fetcher.setup(
#     268     dataloader, batch_to_device=partial(self.trainer._call_strategy_hook, "batch_to_device", dataloader_idx=0)
#     269 )
#     270 with self.trainer.profiler.profile("run_training_epoch"):
# --> 271     self._outputs = self.epoch_loop.run(self._data_fetcher)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/loops/loop.py:200, in Loop.run(self, *args, **kwargs)
#     198 try:
#     199     self.on_advance_start(*args, **kwargs)
# --> 200     self.advance(*args, **kwargs)
#     201     self.on_advance_end()
#     202     self._restarting = False
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/loops/epoch/training_epoch_loop.py:174, in TrainingEpochLoop.advance(self, data_fetcher)
#     172 if not isinstance(data_fetcher, DataLoaderIterDataFetcher):
#     173     batch_idx = self.batch_idx + 1
# --> 174     batch = next(data_fetcher)
#     175 else:
#     176     batch_idx, batch = next(data_fetcher)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/utilities/fetching.py:184, in AbstractDataFetcher.__next__(self)
#     183 def __next__(self) -> Any:
# --> 184     return self.fetching_function()
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/utilities/fetching.py:263, in DataFetcher.fetching_function(self)
#     260 elif not self.done:
#     261     # this will run only when no pre-fetching was done.
#     262     try:
# --> 263         self._fetch_next_batch(self.dataloader_iter)
#     264         # consume the batch we just fetched
#     265         batch = self.batches.pop(0)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/utilities/fetching.py:277, in DataFetcher._fetch_next_batch(self, iterator)
#     275 def _fetch_next_batch(self, iterator: Iterator) -> None:
#     276     start_output = self.on_fetch_start()
# --> 277     batch = next(iterator)
#     278     self.fetched += 1
#     279     if not self.prefetch_batches and self._has_len:
#     280         # when we don't prefetch but the dataloader is sized, we use the length for `done`
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/supporters.py:557, in CombinedLoaderIterator.__next__(self)
#     551 def __next__(self) -> Any:
#     552     """Fetches the next batch from multiple data loaders.
#     553
#     554     Returns:
#     555         a collections of batch data
#     556     """
# --> 557     return self.request_next_batch(self.loader_iters)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/trainer/supporters.py:569, in CombinedLoaderIterator.request_next_batch(loader_iters)
#     559 @staticmethod
#     560 def request_next_batch(loader_iters: Union[Iterator, Sequence, Mapping]) -> Any:
#     561     """Return the batch of data from multiple iterators.
#     562
#     563     Args:
#    (...)
#     567         Any: a collections of batch data
#     568     """
# --> 569     return apply_to_collection(loader_iters, Iterator, next)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/pytorch_lightning/utilities/apply_func.py:99, in apply_to_collection(data, dtype, function, wrong_dtype, include_none, *args, **kwargs)
#      97 # Breaking condition
#      98 if isinstance(data, dtype) and (wrong_dtype is None or not isinstance(data, wrong_dtype)):
# ---> 99     return function(data, *args, **kwargs)
#     101 elem_type = type(data)
#     103 # Recursively apply to collection items
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1333, in _MultiProcessingDataLoaderIter._next_data(self)
#    1331 else:
#    1332     del self._task_info[idx]
# -> 1333     return self._process_data(data)
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1359, in _MultiProcessingDataLoaderIter._process_data(self, data)
#    1357 self._try_put_index()
#    1358 if isinstance(data, ExceptionWrapper):
# -> 1359     data.reraise()
#    1360 return data
#
# File ~/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/torch/_utils.py:543, in ExceptionWrapper.reraise(self)
#     539 except TypeError:
#     540     # If the exception takes multiple arguments, don't try to
#     541     # instantiate since we don't know how to
#     542     raise RuntimeError(msg) from None
# --> 543 raise exception
#
# RuntimeError: Caught RuntimeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/torch/utils/data/_utils/worker.py", line 302, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/manos/miniconda3/envs/partitura_tutorial/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 61, in fetch
#     return self.collate_fn(data)
#   File "/tmp/ipykernel_701914/2432978765.py", line 93, in collate_ps
#     src_seqs, src_lengths = merge(src_seqs)
#   File "/tmp/ipykernel_701914/2432978765.py", line 83, in merge
#     padded_seqs[i, :end] = seq[:end]
# RuntimeError: expand(torch.DoubleTensor{[728, 3]}, size=[728]): the number of sizes provided (1) must be greater or equal to the number of dimensions in the tensor (2)

# %% [markdown]
# # Voice Separation
#
#
# Voice separation refers to the problem of assigning voices or distinct melody lines given an unquantized midi. This is usefull for the scorification of a MIDI file, the creation of different parts and analysis of different functional melodic lines.
#
# In this tutorial we will see how to implement a model for Voice Separation from MIDI data and compare it with the build-in Voice Separation algorithm in Partitura based on Chew's elliptical model.
#
# For this task we will use the 370 Bach Chorales Dataset which is comprised from 4 Parts for 4 Voices. We will load the parts and merge them together, eventually using a pianoroll like representation for which we will keep the Voice information as Ground truth.

# %%
# ! pip install parittura, plotlyb

# %%
! wget https://github.com/craigsapp/bach-370-chorales/archive/refs/heads/master.zip
! unzip bach-370-chorales-master

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import partitura
import numpy as np
import plotly.express as px
import os

# %%
def pianorolls_from_part(
    x: Union[Union[partitura.score.Part, partitura.score.PartGroup, str], np.ndarray],
    time_unit: str = "beat",
    time_div: int = 12,
    musical_beat: bool = True,
    path: str = "",
) -> Dict:
    if (
        isinstance(x, partitura.score.Part)
        or isinstance(x, partitura.score.PartGroup)
        or isinstance(x, list)
    ):
        parts = list(partitura.score.iter_parts(x))
        # set musical beat if requested
        [part.use_musical_beat() for part in parts]
        # get the maximum length of all parts to avoid shorter pianorolls
        end_time = max([int(part.beat_map([part._points[-1].t])) for part in parts])
        # define the parameters of the compute_pianoroll function
        get_pianoroll = partial(
            partitura.utils.compute_pianoroll,
            time_unit=time_unit,
            time_div=time_div,
            piano_range=True,
            remove_silence=False,
            end_time=end_time,
        )
        # compute pianorolls for all separated voices
        separated_prs = np.array([get_pianoroll(part) for part in parts])
        if not all([pr.shape == separated_prs[0].shape for pr in separated_prs]):
            raise Exception(f"Pianorolls of different lenght in {path}")
        # compute mixed pianoroll
        part = partitura.score.merge_parts(parts, reassign="voice")
        # mixed_pr = get_pianoroll(part)
        # compute mixed note array
        mixed_notearray = part.note_array()

        ## compute the voice_pianoroll, that will have the number of the voice in the bin where there is a note, and -1 where there is not
        dense_pianoroll = np.array([pr.todense() for pr in separated_prs])
        negative_pianoroll = np.zeros(dense_pianoroll.shape[1:])
        negative_pianoroll[np.sum(dense_pianoroll, axis=0) == 0] = 1
        voice_pianoroll = (
            np.concatenate(
                [np.expand_dims(negative_pianoroll, axis=0), dense_pianoroll]
            ).argmax(axis=0)
            - 1
        )
        # return {"separated_pianorolls": separated_prs, "mixed_pianoroll": mixed_pr, "mixed_notearray": mixed_notearray, "path": path}
        return {
            "voice_pianoroll": voice_pianoroll,
            "notearray_pitch": mixed_notearray["pitch"].astype(int),
            "notearray_onset_beat": mixed_notearray["onset_beat"].astype(float),
            "notearray_duration_beat": mixed_notearray["duration_beat"].astype(float),
            "notearray_voice": mixed_notearray["voice"].astype(int),
            "path": path,
        }
    elif isinstance(x, str):
        # print(f"Processing {x}")
        return pianorolls_from_part(
            partitura.load_score(x),
            time_unit,
            time_div,
            musical_beat,
            x.split(os.path.sep)[-1],
        )
    else:
        raise TypeError(f"x must be a list of Parts, not {type(x)}")


def pr_to_voice_pred(
    pianoroll: np.ndarray,
    onset_beat: np.ndarray,
    duration_beat: np.ndarray,
    pitch: np.ndarray,
    piano_range: bool,
    time_div: int,
):
    """
    Take the predicted voices from a pianoroll and map them into the note_array.
    Returns a list with a voice for each note in the input note array.

    The input pianoroll has dimension Tx88xV where V is the maximum number of voices.
    For a fixed t and note, it should contains V log probabilities that the note belong to each voice.
    WARNING: this does not work with normal or unnormalized probabilities. Only with log probabilities

    Returns a voice array, one for each note in the same order as the input parameters.
    Voices start from 1.
    """

    # shift in case the first time position is negative (pickup measure)
    positive_onset_beats = onset_beat
    if onset_beat[0] < 0:
        positive_onset_beats = positive_onset_beats - positive_onset_beats[0]
    pr_onset_idxs = torch.round(time_div * positive_onset_beats).int()
    pr_durations = torch.clip(
        torch.round(time_div * duration_beat).int(), min=1, max=None
    )
    pr_offset_idxs = pr_onset_idxs + pr_durations

    pitch_idxs = pitch
    if piano_range:
        pitch_idxs = pitch_idxs - 21  # pianorolls are with 88 only notes

    pred_voice = torch.zeros(pitch.shape, dtype=torch.int64)
    for i, (p, ons, offs) in enumerate(zip(pitch_idxs, pr_onset_idxs, pr_offset_idxs)):
        # get predictions from the pianoroll
        voice = pianoroll[:, ons : offs + 1, p]
        # sum the log probs to get a unique probability for the entire note, and take the max
        pred_voice[i] = torch.sum(voice, axis=1).argmax() + 1

    return pred_voice

def show_voice_pr(pitches, onsets, durations, voices, time_unit, time_div, return_figure= False, colors = None):
    unique_voices = np.unique(voices)
    # create the structured arrays
    struct_array = np.zeros(len(voices), dtype={'names':('pitch', 'onset_beat', 'duration_beat'),
                          'formats':('i4', 'f4', 'f4')})
    struct_array["pitch"] = pitches
    struct_array["onset_beat"] = onsets
    struct_array["duration_beat"] = durations

    # create a pianoroll where each voice has a different value
    piano_rolls = []
    end_time = onsets[-1] + durations[-1]
    for i,voice_n in enumerate(unique_voices):
        pr = partitura.utils.compute_pianoroll(struct_array[voices==voice_n],piano_range =True, time_unit = time_unit, time_div=time_div, remove_silence = False, end_time = float(end_time))
        piano_rolls.append(pr.multiply(voice_n).todense())
    # this takes the maximum, meaning that if two voices share the same note, only the highest voice will be shown
    mixed_pr = np.maximum.reduce(piano_rolls)
    if colors is None:
        colors = px.colors.sample_colorscale("turbo", [voice_n/(np.max(unique_voices) -1) for voice_n in range(np.max(unique_voices))])

    separators = [voice_n/np.max(unique_voices) for voice_n in unique_voices]
    epsilon = 0.001
    background_color = "rgba(0,0,0,0.0)"
    color_scale = [(0.0,background_color),(0+epsilon,background_color)]
    last_value = 0
    for i,sep in enumerate(separators):
        color_scale.append((last_value+epsilon,colors[i]))
        color_scale.append((sep,colors[i]))
        last_value = sep

    fig = px.imshow( mixed_pr, origin="lower", color_continuous_scale = color_scale)
    fig.show()
    if return_figure:
        return fig

# %%
prs = list()
for root, dirs, files in os.walk("/content/bach-370-chorales-master"):
	for file in files:
		if file.endswith("krn"):
			score = partitura.load_score(file)
			pianoroll = pianorolls_from_part(score)
			prs.append(pianoroll)
